# %%
import pandas as pd
import numpy as np

# converts name to GW###### format for visualization purposes
def simplify_name(name):
    if str.startswith(name, "GW"):
        return "GW" + name[2:8]
    return "GW" + name[0:6]

# extracts version number from name
def extract_version(name):
    return name[-1:]

# extracts confidence from catalog.shortName
def extract_group(shortname):
    if "2.1" in shortname:
        return shortname[9:]
    return shortname[7:]

# gets confidence number of group
def extract_confidence(group):
    if group == "confident":
        return 3
    if group == "marginal":
        return 2
    if group == "auxiliary":
        return 1
    return 0

O3_all = pd.read_csv("../Data/GWTC-3.csv")
O3_all["simple_name"] = np.array([simplify_name(name) for name in O3_all["name"]])
O3_all["group"] = np.array([3 for _ in range(O3_all["name"].size)])
O3_all["catalog"] = np.array([extract_group(shortname) for shortname in O3_all["catalog.shortName"]])
O3_all["confidence"] = np.array([extract_confidence(group) for group in O3_all["catalog"]])
O3_all["group_name"] = np.array(["O" + str(group) for group in O3_all["group"]])
O3_all = O3_all[["name", "simple_name", "catalog", "confidence", "version", "group_name", "group", "GPS", "far", "network_matched_filter_snr", "mass_1_source", "mass_2_source", "chirp_mass_source", "redshift", "luminosity_distance", "p_astro", "chi_eff"]]
O3_all = O3_all.rename(columns={"p_astro": "prob", "chi_eff": "effective_spin", "network_matched_filter_snr": "snr", "GPS": "gps", "mass_1_source": "mass1", "mass_2_source": "mass2", "chirp_mass_source": "chirp_mass", "combined_far": "far"})

O2_confident = pd.read_csv("../Data/GWTC-2_1-confident.csv")
O2_confident["simple_name"] = np.array([simplify_name(name) for name in O2_confident["name"]])
O2_confident["group"] = np.array([2 for _ in range(O2_confident["name"].size)])
O2_confident["group_name"] = np.array(["O" + str(group) for group in O2_confident["group"]])
O2_confident["catalog"] = np.array([extract_group(shortname) for shortname in O2_confident["catalog.shortName"]])
O2_confident["confidence"] = np.array([extract_confidence(group) for group in O2_confident["catalog"]])
O2_confident = O2_confident[["name", "simple_name", "catalog", "confidence", "version", "group_name", "group", "GPS", "far", "network_matched_filter_snr", "mass_1_source", "mass_2_source", "chirp_mass_source", "redshift", "luminosity_distance", "p_astro", "chi_eff"]]
O2_confident = O2_confident.rename(columns={"p_astro": "prob", "chi_eff": "effective_spin", "network_matched_filter_snr": "snr", "GPS": "gps", "mass_1_source": "mass1", "mass_2_source": "mass2", "chirp_mass_source": "chirp_mass", "combined_far": "far"})

O2_marginal = pd.read_csv("../Data/GWTC-2_1-marginal.csv")
O2_marginal["simple_name"] = np.array([simplify_name(name) for name in O2_marginal["name"]])
O2_marginal["group"] = np.array([2 for _ in range(O2_marginal["name"].size)])
O2_marginal["group_name"] = np.array(["O" + str(group) for group in O2_marginal["group"]])
O2_marginal["catalog"] = np.array([extract_group(shortname) for shortname in O2_marginal["catalog.shortName"]])
O2_marginal["confidence"] = np.array([extract_confidence(group) for group in O2_marginal["catalog"]])
O2_marginal = O2_marginal[["name", "simple_name", "catalog", "confidence", "version", "group_name", "group", "GPS", "far", "network_matched_filter_snr", "mass_1_source", "mass_2_source", "chirp_mass_source", "redshift", "luminosity_distance", "p_astro", "chi_eff"]]
O2_marginal = O2_marginal.rename(columns={"p_astro": "prob", "chi_eff": "effective_spin", "network_matched_filter_snr": "snr", "GPS": "gps", "mass_1_source": "mass1", "mass_2_source": "mass2", "chirp_mass_source": "chirp_mass", "combined_far": "far"})

O2_auxiliary = pd.read_csv("../Data/GWTC-2_1-auxiliary.csv")
O2_auxiliary["simple_name"] = np.array([simplify_name(name) for name in O2_auxiliary["name"]])
O2_auxiliary["group"] = np.array([2 for _ in range(O2_auxiliary["name"].size)])
O2_auxiliary["group_name"] = np.array(["O" + str(group) for group in O2_auxiliary["group"]])
O2_auxiliary["catalog"] = np.array([extract_group(shortname) for shortname in O2_auxiliary["catalog.shortName"]])
O2_auxiliary["confidence"] = np.array([extract_confidence(group) for group in O2_auxiliary["catalog"]])
O2_auxiliary = O2_auxiliary[["name", "simple_name", "catalog", "confidence", "version", "group_name", "group", "GPS", "far", "network_matched_filter_snr", "mass_1_source", "mass_2_source", "chirp_mass_source", "redshift", "luminosity_distance", "p_astro", "chi_eff"]]
O2_auxiliary = O2_auxiliary.rename(columns={"p_astro": "prob", "chi_eff": "effective_spin", "network_matched_filter_snr": "snr", "GPS": "gps", "mass_1_source": "mass1", "mass_2_source": "mass2", "chirp_mass_source": "chirp_mass", "combined_far": "far"})

O1_all = pd.read_csv("../Data/GWTC-1.csv")
O1_all["simple_name"] = np.array([simplify_name(name) for name in O1_all["name"]])
O1_all["group"] = np.array([1 for _ in range(O1_all["name"].size)])
O1_all["catalog"] = np.array([extract_group(shortname) for shortname in O1_all["catalog.shortName"]])
O1_all["confidence"] = np.array([extract_confidence(group) for group in O1_all["catalog"]])
O1_all["group_name"] = np.array(["O" + str(group) for group in O1_all["group"]])
O1_all = O1_all[["name", "simple_name", "catalog", "confidence", "version", "group_name", "group", "GPS", "far", "network_matched_filter_snr", "mass_1_source", "mass_2_source", "chirp_mass_source", "redshift", "luminosity_distance", "p_astro", "chi_eff"]]
O1_all = O1_all.rename(columns={"p_astro": "prob", "chi_eff": "effective_spin", "network_matched_filter_snr": "snr", "GPS": "gps", "mass_1_source": "mass1", "mass_2_source": "mass2", "chirp_mass_source": "chirp_mass", "combined_far": "far"})

observations = pd.concat([O3_all, O2_confident, O2_marginal, O2_auxiliary, O1_all])

observations["total_mass"] = observations["mass1"] + observations["mass2"]
observations["mass_ratio"] = observations["mass1"] / observations["mass2"]
observations["mass_dos"] = abs(observations["mass2"] - observations["mass1"]) / observations["total_mass"]

observations["is_O1"] = observations["group"] == 1
observations["is_O2"] = observations["group"] == 2
observations["is_O3"] = observations["group"] == 3

confident = observations[observations['confidence'] == 3]

O3 = confident[confident['group'] == 3]
O2 = confident[confident['group'] == 2]
O1 = confident[confident['group'] == 1]

O4_all = pd.read_csv("../Data/O4_ALL_Feb_pull.csv")
O4_all = O4_all[["eventid", "chirp_mass", "combined_far", "mass1", "mass2", "snr", "spin1z", "spin2z", "template_duration", "likelihood"]]
O4_all["group"] = np.array([4 for _ in range(O4_all["eventid"].size)])
O4_all["group_name"] = np.array(["O" + str(group) for group in O4_all["group"]])
O4_all = O4_all.rename(columns={"combined_far": "far"})

O3_all = pd.read_csv("../Data/real_events_O3_ALL.csv")
O3_all = O3_all[["eventid", "chirp_mass", "combined_far", "mass1", "mass2", "snr", "spin1z", "spin2z", "template_duration", "chisq", "likelihood"]]
O3_all["group"] = np.array([3 for _ in range(O3_all["eventid"].size)])
O3_all["group_name"] = np.array(["O" + str(group) for group in O3_all["group"]])
O3_all = O3_all.rename(columns={"combined_far": "far"})

events = pd.concat([O4_all, O3_all])

events["total_mass"] = events["mass1"] + events["mass2"]
events["mass_ratio"] = events["mass1"] / events["mass2"]
events["mass_dos"] = abs(events["mass2"] - events["mass1"]) / events["total_mass"]
events["effective_spin"] = events["spin1z"] + events["spin2z"]
events["chi_eff"] = events["effective_spin"]

events_BBH = events[events["mass2"] > 2.16]
events_BNS = events[events["mass2"] <= 2.16]

O4_events = events[events['group'] == 4]
O4 = O4_events
O3_events = events[events['group'] == 3]

O1_BBH = O1[O1["mass2"] > 2.16]
O2_BBH = O2[O2["mass2"] > 2.16]
O3_BBH = O3[O3["mass2"] > 2.16]
O3_BNS = O3[O3["mass2"] <= 2.16]
O3_events_BBH = O3_events[O3_events["mass2"] > 2.16]
O3_events_BNS = O3_events[O3_events["mass2"] <= 2.16]
O4_BBH = O4_events[O4_events["mass2"] > 2.16]
O4_events_BBH = O4_BBH
O4_BNS = O4_events[O4_events["mass2"] <= 2.16]
O4_events_BNS = O4_BNS

# %% [markdown]
# - **observations** : all events from GWTC including marginal and auxiliary
# - **confident** : all events from GWTC marked as confident
# - **O3** : all O3 events from GWTC marked as confident
# - **O2** : all O2 events from GWTC marked as confident
# - **O1** : all O1 events from GWTC marked as confident
# - **events** : all events from "real_events_O4_ALL.csv" and "real_events_O3_ALL.csv"
# - **events_BBH** : all black hole mergers from "real_events_O4_ALL.csv" and "real_events_O3_ALL.csv"
# - **events_BNS** : all neuron star mergers from "real_events_O4_ALL.csv" and "real_events_O3_ALL.csv"
# - **O4_events** *-or-* **O4** : all O4 events from "real_events_O4_ALL.csv"
# - **O3_events** : all O3 events from "real_events_O3_ALL.csv"
# - **O1_BBH** : all confident O1 black hole mergers from GWTC
# - **O2_BBH** : all confident O2 black hole mergers from GWTC
# - **O3_BBH** : all confident O3 black hole mergers from GWTC
# - **O3_BNS** : all confident O3 neuron star mergers from GWTC
# - **O3_real_BBH** : all O3 black hole mergers from "real_events_O3_ALL.csv"
# - **O3_real_BNS** : all O3 neuron star mergers from "real_events_O3_ALL.csv"
# - **O4_BBH** : all O4 black hole mergers from "real_events_O4_ALL.csv"
# - **O4_BNS** : all O4 neuron star mergers from "real_events_O4_ALL.csv"
#
# **Important** Dataframes:
#
# - **O1**, **O2**, **O3**, **O4** : all observations which confident from the GWTC and "real_events_O4_ALL.csv"
# - **O3_BBH**, **O3_BNS**, **O4_BBH**, **O4_BNS** : all observations of binary black hole mergers and neuron star mergers from "GWTC-3-confident.csv" and "real_events_O4_ALL.csv"

# %%
observations.head()
# Out:
#                  name simple_name    catalog  confidence  version group_name  \
# 0  GW200322_091133-v1    GW200322  confident           3        1         O3
# 1  GW200316_215756-v1    GW200316  confident           3        1         O3
# 2  GW200311_115853-v1    GW200311  confident           3        1         O3
# 3  GW200308_173609-v1    GW200308  confident           3        1         O3
# 4  GW200306_093714-v1    GW200306  confident           3        1         O3
#
#    group           gps        far   snr  ...  redshift  luminosity_distance  \
# 0      3  1.268904e+09  140.00000   4.5  ...      0.59               3500.0
# 1      3  1.268431e+09    0.00001  10.3  ...      0.22               1120.0
# 2      3  1.267963e+09    0.00001  17.8  ...      0.23               1170.0
# 3      3  1.267724e+09    2.40000   4.7  ...      1.04               7100.0
# 4      3  1.267523e+09   24.00000   7.8  ...      0.38               2100.0
#
#       prob  effective_spin  total_mass  mass_ratio  mass_dos  is_O1  is_O2  \
# 0  0.61501            0.27        49.3    3.362832  0.541582  False  False
# 1  0.99000            0.13        20.9    1.679487  0.253589  False  False
# 2  0.99000           -0.02        61.9    1.234657  0.105008  False  False
# 3  0.85660            0.16        84.0    2.500000  0.428571  False  False
# 4  0.81156            0.32        43.1    1.912162  0.313225  False  False
#
#    is_O3
# 0   True
# 1   True
# 2   True
# 3   True
# 4   True
#
# [5 rows x 23 columns]

# %% [markdown]
# Above is the format for all data from GWTC data. Dataframes with this format are: **observations**, **confident**, **O3**, **O3_BBH**, **O3_BNS**, **O2**, and **O1**.

# %%
events.head()
# Out:
#      eventid  chirp_mass           far       mass1      mass2        snr  \
# 0   S240109a   23.223027  7.346090e-09   36.045074  20.078638  10.434701
# 1   S240107b   49.904044  5.834248e-08  123.678850  29.247703   7.584719
# 2  S240104bl   41.086045  3.554967e-17   54.746231  40.860004  14.819963
# 3  S231231ag   20.645648  8.354028e-15   25.801163  21.829105  13.558277
# 4  S231226av   39.445388  1.113964e-50   50.356155  40.860004  26.316437
#
#      spin1z    spin2z  template_duration  likelihood  group group_name  chisq  \
# 0 -0.278438 -0.278438               17.0   17.739817      4         O4    NaN
# 1  0.355781  0.355781                0.0   15.856870      4         O4    NaN
# 2  0.046406  0.046406               17.0   34.786927      4         O4    NaN
# 3 -0.030937 -0.030937               17.0   30.108771      4         O4    NaN
# 4 -0.077344 -0.077344               17.0  108.349365      4         O4    NaN
#
#    total_mass  mass_ratio  mass_dos  effective_spin   chi_eff
# 0   56.123712    1.795195  0.284486       -0.556875 -0.556875
# 1  152.926553    4.228669  0.617493        0.711562  0.711562
# 2   95.606235    1.339849  0.145244        0.092813  0.092813
# 3   47.630268    1.181962  0.083394       -0.061875 -0.061875
# 4   91.216159    1.232407  0.104106       -0.154687 -0.154687

# %% [markdown]
# Above is the format for all data from GWTC data. Dataframes with this format are: **events**, **events_BBH**, **events_BNS**, **O3_events**, **O3_events_BBH**, **O3_events_BNS**, **O4_events**, **O4**, **O4_BBH**, and **O4_BNS**.

# %% [markdown]
# ---

# %% [markdown]
# To be **backwards compatable** with previously written code, include the following cell.

# %%
observations["mass_1_source"] = observations["mass1"]
observations["mass_2_source"] = observations["mass2"]
observations["network_matched_filter_snr"] = observations["snr"]
observations["chi_eff"] = observations["effective_spin"]
observations["chirp_mass_source"] = observations["chirp_mass"]
observations["combined_far"] = observations["far"]
observations["p_astro"] = observations["prob"]
observations["network_matched_filter_snr"] = observations["snr"]
observations["M_tot"] = observations["total_mass"]

confident["mass_1_source"] = confident["mass1"]
confident["mass_2_source"] = confident["mass2"]
confident["network_matched_filter_snr"] = confident["snr"]
confident["chi_eff"] = confident["effective_spin"]
confident["chirp_mass_source"] = confident["chirp_mass"]
confident["combined_far"] = confident["far"]
confident["p_astro"] = confident["prob"]
confident["network_matched_filter_snr"] = confident["snr"]
observations["M_tot"] = observations["total_mass"]

O3["mass_1_source"] = O3["mass1"]
O3["mass_2_source"] = O3["mass2"]
O3["network_matched_filter_snr"] = O3["snr"]
O3["chi_eff"] = O3["effective_spin"]
O3["chirp_mass_source"] = O3["chirp_mass"]
O3["combined_far"] = O3["far"]
O3["p_astro"] = O3["prob"]
O3["network_matched_filter_snr"] = O3["snr"]
O3["M_tot"] = O3["total_mass"]
O3_all = O3

O3_BBH["mass_1_source"] = O3_BBH["mass1"]
O3_BBH["mass_2_source"] = O3_BBH["mass2"]
O3_BBH["network_matched_filter_snr"] = O3_BBH["snr"]
O3_BBH["chi_eff"] = O3_BBH["effective_spin"]
O3_BBH["chirp_mass_source"] = O3_BBH["chirp_mass"]
O3_BBH["combined_far"] = O3_BBH["far"]
O3_BBH["p_astro"] = O3_BBH["prob"]
O3_BBH["network_matched_filter_snr"] = O3_BBH["snr"]
O3_BBH["M_tot"] = O3_BBH["total_mass"]
O3_BBH_all = O3_BBH
O3_clean = O3_BBH

O3_BNS["mass_1_source"] = O3_BNS["mass1"]
O3_BNS["mass_2_source"] = O3_BNS["mass2"]
O3_BNS["network_matched_filter_snr"] = O3_BNS["snr"]
O3_BNS["chi_eff"] = O3_BNS["effective_spin"]
O3_BNS["chirp_mass_source"] = O3_BNS["chirp_mass"]
O3_BNS["combined_far"] = O3_BNS["far"]
O3_BNS["p_astro"] = O3_BNS["prob"]
O3_BNS["network_matched_filter_snr"] = O3_BNS["snr"]
O3_BNS["M_tot"] = O3_BNS["total_mass"]
O3_BNS_all = O3_BNS

O2["mass_1_source"] = O2["mass1"]
O2["mass_2_source"] = O2["mass2"]
O2["network_matched_filter_snr"] = O2["snr"]
O2["chi_eff"] = O2["effective_spin"]
O2["chirp_mass_source"] = O2["chirp_mass"]
O2["combined_far"] = O2["far"]
O2["p_astro"] = O2["prob"]
O2["network_matched_filter_snr"] = O2["snr"]
O2["M_tot"] = O2["total_mass"]
O2_all = O2
O2_clean = O2[O2["mass2"] > 2.16]

O1["mass_1_source"] = O1["mass1"]
O1["mass_2_source"] = O1["mass2"]
O1["network_matched_filter_snr"] = O1["snr"]
O1["chi_eff"] = O1["effective_spin"]
O1["chirp_mass_source"] = O1["chirp_mass"]
O1["combined_far"] = O1["far"]
O1["p_astro"] = O1["prob"]
O1["network_matched_filter_snr"] = O1["snr"]
O1["M_tot"] = O1["total_mass"]
O1_all = O1

events["network_matched_filter_snr"] = events["snr"]
events["combined_far"] = events["far"]
events["M_tot"] = events["total_mass"]

events_BBH["network_matched_filter_snr"] = events_BBH["snr"]
events_BBH["combined_far"] = events_BBH["far"]
events_BBH["M_tot"] = events_BBH["total_mass"]

events_BNS["network_matched_filter_snr"] = events_BNS["snr"]
events_BNS["combined_far"] = events_BNS["far"]
events_BNS["M_tot"] = events_BNS["total_mass"]

O3_events["network_matched_filter_snr"] = O3_events["snr"]
O3_events["combined_far"] = O3_events["far"]
O3_events["M_tot"] = O3_events["total_mass"]

O3_events_BBH["network_matched_filter_snr"] = O3_events_BBH["snr"]
O3_events_BBH["combined_far"] = O3_events_BBH["far"]
O3_events_BBH["M_tot"] = O3_events_BBH["total_mass"]

O3_events_BNS["network_matched_filter_snr"] = O3_events_BNS["snr"]
O3_events_BNS["combined_far"] = O3_events_BNS["far"]
O3_events_BNS["M_tot"] = O3_events_BNS["total_mass"]

O4_events["network_matched_filter_snr"] = O4_events["snr"]
O4_events["combined_far"] = O4_events["far"]
O4_events["M_tot"] = O4_events["total_mass"]
O4 = O4_events

O4_events_BBH["network_matched_filter_snr"] = O4_events_BBH["snr"]
O4_events_BBH["combined_far"] = O4_events_BBH["far"]
O4_events_BBH["M_tot"] = O4_events_BBH["total_mass"]
O4_BBH = O4_events_BBH
O4_clean = O4_events_BBH

O4_events_BNS["network_matched_filter_snr"] = O4_events_BNS["snr"]
O4_events_BNS["combined_far"] = O4_events_BNS["far"]
O4_events_BNS["M_tot"] = O4_events_BNS["total_mass"]
O4_BNS = O4_events_BNS
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   confident["mass_1_source"] = confident["mass1"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   confident["mass_2_source"] = confident["mass2"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   confident["network_matched_filter_snr"] = confident["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   confident["chi_eff"] = confident["effective_spin"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   confident["chirp_mass_source"] = confident["chirp_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   confident["combined_far"] = confident["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   confident["p_astro"] = confident["prob"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   confident["network_matched_filter_snr"] = confident["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3["mass_1_source"] = O3["mass1"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3["mass_2_source"] = O3["mass2"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3["network_matched_filter_snr"] = O3["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3["chi_eff"] = O3["effective_spin"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3["chirp_mass_source"] = O3["chirp_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3["combined_far"] = O3["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3["p_astro"] = O3["prob"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3["network_matched_filter_snr"] = O3["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3["M_tot"] = O3["total_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BBH["mass_1_source"] = O3_BBH["mass1"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BBH["mass_2_source"] = O3_BBH["mass2"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BBH["network_matched_filter_snr"] = O3_BBH["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BBH["chi_eff"] = O3_BBH["effective_spin"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BBH["chirp_mass_source"] = O3_BBH["chirp_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BBH["combined_far"] = O3_BBH["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BBH["p_astro"] = O3_BBH["prob"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BBH["network_matched_filter_snr"] = O3_BBH["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BBH["M_tot"] = O3_BBH["total_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BNS["mass_1_source"] = O3_BNS["mass1"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BNS["mass_2_source"] = O3_BNS["mass2"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BNS["network_matched_filter_snr"] = O3_BNS["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BNS["chi_eff"] = O3_BNS["effective_spin"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BNS["chirp_mass_source"] = O3_BNS["chirp_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BNS["combined_far"] = O3_BNS["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BNS["p_astro"] = O3_BNS["prob"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BNS["network_matched_filter_snr"] = O3_BNS["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_BNS["M_tot"] = O3_BNS["total_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O2["mass_1_source"] = O2["mass1"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O2["mass_2_source"] = O2["mass2"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O2["network_matched_filter_snr"] = O2["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O2["chi_eff"] = O2["effective_spin"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O2["chirp_mass_source"] = O2["chirp_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O2["combined_far"] = O2["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O2["p_astro"] = O2["prob"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O2["network_matched_filter_snr"] = O2["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O2["M_tot"] = O2["total_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O1["mass_1_source"] = O1["mass1"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O1["mass_2_source"] = O1["mass2"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O1["network_matched_filter_snr"] = O1["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O1["chi_eff"] = O1["effective_spin"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O1["chirp_mass_source"] = O1["chirp_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O1["combined_far"] = O1["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O1["p_astro"] = O1["prob"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O1["network_matched_filter_snr"] = O1["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O1["M_tot"] = O1["total_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   events_BBH["network_matched_filter_snr"] = events_BBH["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   events_BBH["combined_far"] = events_BBH["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   events_BBH["M_tot"] = events_BBH["total_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   events_BNS["network_matched_filter_snr"] = events_BNS["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   events_BNS["combined_far"] = events_BNS["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   events_BNS["M_tot"] = events_BNS["total_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_events["network_matched_filter_snr"] = O3_events["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_events["combined_far"] = O3_events["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_events["M_tot"] = O3_events["total_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_events_BBH["network_matched_filter_snr"] = O3_events_BBH["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_events_BBH["combined_far"] = O3_events_BBH["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_events_BBH["M_tot"] = O3_events_BBH["total_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_events_BNS["network_matched_filter_snr"] = O3_events_BNS["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_events_BNS["combined_far"] = O3_events_BNS["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_events_BNS["M_tot"] = O3_events_BNS["total_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O4_events["network_matched_filter_snr"] = O4_events["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O4_events["combined_far"] = O4_events["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O4_events["M_tot"] = O4_events["total_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O4_events_BBH["network_matched_filter_snr"] = O4_events_BBH["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O4_events_BBH["combined_far"] = O4_events_BBH["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O4_events_BBH["M_tot"] = O4_events_BBH["total_mass"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O4_events_BNS["network_matched_filter_snr"] = O4_events_BNS["snr"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O4_events_BNS["combined_far"] = O4_events_BNS["far"]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_11136\3505974667.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O4_events_BNS["M_tot"] = O4_events_BNS["total_mass"]

# %% [markdown]
# ---

# %% [markdown]
# This following cell is for my little adventure with predicting luminoisty distance with machine learning.

# %%
O3_all_predicted = pd.read_csv("../Data Analysis/PredictedData/O3_ALL_predicted.csv")
O3_mock = pd.read_csv("../Data Analysis/PredictedData/O3_mock.csv")

# %% [markdown]
# ---

# %% [markdown]
# Attempting to find overlap in "real_events_O3_ALL.csv" and "GWTC-3-confident.csv"

# %%
import matplotlib.pyplot as plt

# %%
chirp_mass_threshhold = 1
total_mass_threshhold = 1
SNR_threshhold = 0.5
eff_spin_threshhold = 10

# display settings
rounding = 2
barWidth = 0.5

# %%
overlap = list()
for _, event in O3_events.iterrows():
    for _, other_event in O3.iterrows():
        if abs(event["chirp_mass"] - other_event["chirp_mass"]) <= chirp_mass_threshhold and abs(event["total_mass"] - other_event["total_mass"]) <= total_mass_threshhold and abs(event["snr"] - other_event["snr"]) <= SNR_threshhold and abs(event["spin1z"] + event["spin2z"] - other_event["chi_eff"]) <= eff_spin_threshhold:
            overlap.append((event, other_event))

# %%
for pair in overlap:
    real_event, GWTC_event = pair
    print("Catalog", "id        ", "mass1     ", "mass2     ", "total_mass", "chirp_mass", "snr       ", "spin1z    ", "spin2z    ", "eff_spin? ")
    print("Real   ", str.ljust(real_event["eventid"], 10), str.ljust(str(round(real_event["mass1"], rounding)), 10), str.ljust(str(round(real_event["mass2"], rounding)), 10), str.ljust(str(round(real_event["total_mass"], rounding)), 10), str.ljust(str(round(real_event["chirp_mass"], rounding)), 10), str.ljust(str(round(real_event["snr"], rounding)), 10), str.ljust(str(round(real_event["spin1z"], rounding)), 10), str.ljust(str(round(real_event["spin2z"], rounding)), 10), str.ljust(str(round(real_event["spin1z"] + real_event["spin2z"], rounding)), 10))
    print("GWTC   ", str.ljust(GWTC_event["simple_name"], 10), str.ljust(str(round(GWTC_event["mass1"], rounding)), 10), str.ljust(str(round(GWTC_event["mass2"], rounding)), 10), str.ljust(str(round(GWTC_event["total_mass"], rounding)), 10), str.ljust(str(round(GWTC_event["chirp_mass"], rounding)), 10), str.ljust(str(round(GWTC_event["snr"], rounding)), 10), str.ljust("NaN", 10), str.ljust("NaN", 10), str.ljust(str(round(GWTC_event["chi_eff"], rounding)), 10))
    print()
# Out:
# Catalog id         mass1      mass2      total_mass chirp_mass snr        spin1z     spin2z     eff_spin?
# Real    S200302c   47.14      27.4       74.54      31.06      10.74      0.36       -0.6       -0.24
# GWTC    GW200128   42.2       32.6       74.8       32.0       10.6       NaN        NaN        0.12
#
# Catalog id         mass1      mass2      total_mass chirp_mass snr        spin1z     spin2z     eff_spin?
# Real    S191129u   13.1       7.43       20.52      8.52       8.55       0.12       0.1        0.22
# GWTC    GW191126   12.1       8.3        20.4       8.65       8.3        NaN        NaN        0.21
#
# Catalog id         mass1      mass2      total_mass chirp_mass snr        spin1z     spin2z     eff_spin?
# Real    S191129u   13.1       7.43       20.52      8.52       8.55       0.12       0.1        0.22
# GWTC    GW191103   11.8       7.9        19.7       8.34       8.9        NaN        NaN        0.21
#
# Catalog id         mass1      mass2      total_mass chirp_mass snr        spin1z     spin2z     eff_spin?
# Real    S190828l   30.38      12.92      43.31      16.95      7.63       -0.24      0.69       0.45
# GWTC    GW200306   28.3       14.8       43.1       17.5       7.8        NaN        NaN        0.32

# %%
fig, ax = plt.subplots(6, figsize=(5, 20), layout='constrained', dpi=110)

combined_overlap = list()
ele = 0
#GWTC_overlap = list()
for pair in overlap:
    real_event, GWTC_event = pair
    real_event["id"] = real_event["eventid"]
    real_event["color"] = "r"
    real_event["label"] = "Real"
    real_event["ele"] = ele
    combined_overlap.append(real_event)
    GWTC_event["id"] = GWTC_event["simple_name"]
    GWTC_event["color"] = "b"
    GWTC_event["label"] = "GWTC"
    GWTC_event["ele"] = ele + barWidth
    combined_overlap.append(GWTC_event)
    ele += barWidth * 2.25
combined_overlap = pd.concat(combined_overlap)

indices = [0,1,2,3,4,5]
labels = ["mass1", "mass2", "total_mass", "chirp_mass", "snr", "chi_eff"]
for label, i in zip(labels, indices):
    ax[i].barh(combined_overlap['ele'], combined_overlap[label], barWidth, color=combined_overlap["color"])
    ax[i].set_yticks(np.array(combined_overlap['ele'], dtype=float), labels=combined_overlap['id'])
    ax[i].invert_yaxis()
    ax[i].set_title(label)

plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import BayesianRidge

train, test = train_test_split(O3_events, test_size=0.33)

model = BayesianRidge()
model.fit(train[["chirp_mass", "combined_far", "mass1", "mass2", "snr", "spin1z", "spin2z"]], train["template_duration"])

model.score(test[["chirp_mass", "combined_far", "mass1", "mass2", "snr", "spin1z", "spin2z"]], test["template_duration"])
# Out:
# -3.602032978364659
